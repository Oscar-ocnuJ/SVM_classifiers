# %%
# %matplotlib notebook

# Principal Component Analysis on training and test data sets
import joblib
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %%
# Import the 20k samples dataset
filename = 'datasets/mnist20k.dataset_job'
dataset = joblib.load(filename)

# Dataset preparation
# Split the MNIST dataset in training and testing sets
print("Separating dataset in training and testing sets ...")
test_ratio = 0.2
dataset.separate_train_test(test_ratio)
print(f"Dataset separated, we have a {100 * test_ratio} % of samples for the test set!")
# Out:
# Separating dataset in training and testing sets ...
# Size of training set: 16000 / 20000
# Size of testing set: 4000 / 20000
# Dataset separated, we have a 20.0 % of samples for the test set!

# %%
# PCA
pca = PCA(n_components=3)
X_train = pca.fit_transform(dataset.X_train)
X_test = pca.transform(dataset.X_test)
print(f"Variance ratio : {np.sum(pca.explained_variance_ratio_[0:2])}")
# Out:
# Variance ratio : 0.169095909601144

# %%
y_train = dataset.y_train
u_labels = np.unique(y_train)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
for i in u_labels:
    print()
    ax.scatter(X_train[ y_train== i][:,0] , X_train[y_train == i][:,1], X_train[ y_train== i][:, 2] ,label = i)

ax.set_xlabel('Comp1')
ax.set_ylabel('Comp2')
ax.set_zlabel('Comp3')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
